# %%
#importing libraries
import numpy as np
import pandas as pd
data = pd.read_csv("instagram_global_top_1000.csv")

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
data
# Out:
#     Country  Rank                       Account  \
# 0       All     1                     cristiano
# 1       All     2                   kyliejenner
# 2       All     3                      leomessi
# 3       All     4                 kendalljenner
# 4       All     5                   selenagomez
# 5       All     6                       zendaya
# 6       All     7                 kimkardashian
# 7       All     8                       beyonce
# 8       All     9                  arianagrande
# 9       All    10                  billieeilish
# 10      All    11                      neymarjr
# 11      All    12                  lalalalisa_m
# 12      All    13                jennierubyjane
# 13      All    14                tomholland2013
# 14      All    15                   virat.kohli
# 15      All    16    abcdefghi__lmnopqrstuvwxyz
# 16      All    17                       khaby00
# 17      All    18               khloekardashian
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   float64
#  7   Audience Country      993 non-null    object
#  8   Authentic engagement  1000 non-null   float64
#  9   Engagement avg        1000 non-null   float64
#  10  Scraped               1000 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
data.shape
# Out:
# (1000, 11)

# %%
# using describe to get the basic statistics of the dataframe
data.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Account                 0
# Title                   0
# Link                    0
# Category                0
# Followers               0
# Audience Country        0
# Authentic engagement    0
# Engagement avg          0
# dtype: int64

# %%
data = data.fillna({'Audience Country':'United States'})

# %%
data = data.fillna({'Category':'Music|Modeling'})

# %%
data=data.fillna(method = 'pad',axis = 1)

# %%
data.drop(["Country", "Scraped"], axis = 1, inplace = True)

# %%
data = data.astype({"Followers":"int","Authentic engagement":"int","Engagement avg":"int"})

# %%
data.pivot_table(index="Category", values="Followers", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                             mean  \
#                                                        Followers
# Category
# Sports with a ball                                  3.225825e+07
# Fashion|Modeling|Beauty                             3.088000e+08
# Sports with a ball|Family                           1.730500e+08
# Modeling|Fashion                                    6.622500e+07
# Music|Lifestyle                                     4.848000e+07
# Cinema|Actors/actresses|Fashion                     1.278000e+08
# Fashion|Beauty                                      2.849000e+08
# Music|Fashion                                       1.045000e+08
# Music                                               2.837294e+07
# Cinema|Actors/actresses                             2.250182e+07
# Music|Modeling                                      9.423404e+06
# Clothing|Outfits|Lifestyle                          1.264000e+08
# ...

# %%
data.pivot_table(index="Category", values="Engagement avg", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                              mean  \
#                                                    Engagement avg
# Category
# Sports with a ball                                   6.432223e+05
# Fashion|Modeling|Beauty                              1.010000e+07
# Sports with a ball|Family                            3.612750e+06
# Modeling|Fashion                                     1.714450e+06
# Music|Lifestyle                                      1.201450e+06
# Cinema|Actors/actresses|Fashion                      7.800000e+06
# Fashion|Beauty                                       3.300000e+06
# Music|Fashion                                        2.658500e+06
# Music                                                9.646524e+05
# Cinema|Actors/actresses                              8.305394e+05
# Music|Modeling                                       1.689267e+06
# Clothing|Outfits|Lifestyle                           1.900000e+06
# ...

# %%
# returning the relative frequency of audience country elements
data['Audience Country'].value_counts(normalize=True).round(2)
# Out:
# United States           0.29
# Brazil                  0.16
# India                   0.14
# Indonesia               0.13
# Mexico                  0.05
# Spain                   0.03
# Russia                  0.03
# Argentina               0.02
# Iran                    0.02
# United Kingdom          0.02
# Turkey                  0.02
# Italy                   0.02
# South Korea             0.01
# Colombia                0.01
# Philippines             0.01
# France                  0.01
# Egypt                   0.01
# Germany                 0.00
# Nigeria                 0.00
# Thailand                0.00
# Iraq                    0.00
# Morocco                 0.00
# Japan                   0.00
# Saudi Arabia            0.00
# Kazakhstan              0.00
# Syria                   0.00
# China                   0.00
# Algeria                 0.00
# United Arab Emirates    0.00
# Poland                  0.00
# Chile                   0.00
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns 
plt.figure(figsize=(35,10))
sns.countplot(x="Audience Country", data = data)
plt.title("Relative Frequency of Audience Country",fontsize =20)
plt.xlabel("Audience Country",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.show()

# %%
topfollowers = data.nlargest(10,'Followers')

topfollowers.pivot_table(index="Category", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                                            sum
#                                      Followers
# Category
# Photography                          469600000
# Sports with a ball                   400100000
# Fashion|Modeling|Beauty              308800000
# Sports with a ball|Family            306300000
# Music|Lifestyle                      295800000
# Cinema|Actors/actresses|Fitness|Gym  295800000
# Music                                513900000
# Fashion|Beauty                       284900000
# Music|Fashion                        237200000

# %%
topfollowers20 = data.nlargest(20,'Followers')

topfollowers20.pivot_table(index="Category", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                                                     sum
#                                               Followers
# Category
# Photography                                   469600000
# Sports with a ball                            752500000
# Fashion|Modeling|Beauty                       308800000
# Sports with a ball|Family                     306300000
# Music|Lifestyle                               295800000
# Cinema|Actors/actresses|Fitness|Gym           295800000
# Music                                         848100000
# Fashion|Beauty                                284900000
# Music|Fashion                                 237200000
# Clothing|Outfits|Lifestyle                    219400000
# Modeling|Fashion                              217800000
# Nature  landscapes|Science|Photography        206600000
# Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000
# Music|Cinema|Actors/actresses                 194900000
# Lifestyle                                     162200000

# %%
df_usa = data[data['Audience Country'] == 'United States']
df_ind = data[data['Audience Country'] == 'India']
df_bra = data[data['Audience Country'] == 'Brazil']
df_indo = data[data['Audience Country'] == 'Indonesia']
df_mex = data[data['Audience Country'] == 'Mexico']

# %%
df_usa.head()
# Out:
#   Rank        Account                Title  \
# 1    2    kyliejenner              Kylie 🤍
# 3    4  kendalljenner              Kendall
# 4    5    selenagomez         Selena Gomez
# 5    6        zendaya              Zendaya
# 6    7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#    Followers Audience Country  Authentic engagement  Engagement avg
# 1  308800000    United States               6200000        10100000
# 3  217800000    United States               3400000         5400000
# ...

# %%
df_ind.head()
# Out:
#    Rank       Account              Title  \
# 0     1     cristiano  Cristiano Ronaldo
# 14   15   virat.kohli        Virat Kohli
# 19   20  justinbieber      Justin Bieber
# 27   28       therock            therock
# 28   29     instagram          Instagram
#
#                                        Link  \
# 0      https://www.instagram.com/cristiano/
# 14   https://www.instagram.com/virat.kohli/
# 19  https://www.instagram.com/justinbieber/
# 27       https://www.instagram.com/therock/
# 28     https://www.instagram.com/instagram/
#
#                                Category  Followers Audience Country  \
# 0                    Sports with a ball  400100000            India
# 14                   Sports with a ball  182600000            India
# 19                                Music  219800000            India
# 27  Cinema|Actors/actresses|Fitness|Gym  295800000            India
# 28                          Photography  469600000            India
#
# ...

# %%
df_indo.head()
# Out:
#    Rank          Account   Title                                        Link  \
# 11   12     lalalalisa_m    LISA     https://www.instagram.com/lalalalisa_m/
# 12   13   jennierubyjane       J   https://www.instagram.com/jennierubyjane/
# 18   19        sooyaaa__  JISOO🤍        https://www.instagram.com/sooyaaa__/
# 21   22  roses_are_rosie   ROSÉ  https://www.instagram.com/roses_are_rosie/
# 45   46        eunwo.o_c     차은우        https://www.instagram.com/eunwo.o_c/
#
#            Category  Followers Audience Country  Authentic engagement  \
# 11            Music   73100000        Indonesia               7500000
# 12            Music   62300000        Indonesia               6400000
# 18     Music|Beauty   56100000        Indonesia               6300000
# 21            Music   55100000        Indonesia               5500000
# 45  Music|Lifestyle   26500000        Indonesia               3700000
#
#     Engagement avg
# 11         8600000
# 12         7600000
# 18         7200000
# ...

# %%
df_bra.head()
# Out:
#    Rank           Account               Title  \
# 10   11          neymarjr               NJ 🇧🇷
# 37   38       harrystyles         harrystyles
# 55   56       shawnmendes        Shawn Mendes
# 56   57  milliebobbybrown  Millie Bobby Brown
# 63   64        ursulolita  Úrsula Corberó 🐣
#
#                                            Link  \
# 10          https://www.instagram.com/neymarjr/
# 37       https://www.instagram.com/harrystyles/
# 55       https://www.instagram.com/shawnmendes/
# 56  https://www.instagram.com/milliebobbybrown/
# 63        https://www.instagram.com/ursulolita/
#
#                             Category  Followers Audience Country  \
# 10                Sports with a ball  169800000           Brazil
# 37                     Music|Fashion   43000000           Brazil
# 55                             Music   66500000           Brazil
# 56           Cinema|Actors/actresses   47500000           Brazil
# ...

# %%
df_mex.head()
# Out:
#     Rank          Account         Title  \
# 41    42           karolg       KAROL G
# 46    47          dualipa      DUA LIPA
# 62    63         lelepons     Lele Pons
# 74    75  kimberly.loaiza  KIM LOAIZA 🖤
# 114  115       songkang_b        송강
#
#                                            Link                    Category  \
# 41            https://www.instagram.com/karolg/                       Music
# 46           https://www.instagram.com/dualipa/                       Music
# 62          https://www.instagram.com/lelepons/                       Music
# 74   https://www.instagram.com/kimberly.loaiza/  Clothing|Outfits|Lifestyle
# 114       https://www.instagram.com/songkang_b/              Music|Modeling
#
#      Followers Audience Country  Authentic engagement  Engagement avg
# 41    47300000           Mexico               2600000         3200000
# 46    78700000           Mexico               1200000         1400000
# ...

# %%
topfollowers_usa = df_usa.nlargest(10,'Followers')

topfollowers_usa.pivot_table(index="Category", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                                                     sum
#                                               Followers
# Category
# Fashion|Modeling|Beauty                       308800000
# Music|Lifestyle                               295800000
# Music                                         294100000
# Fashion|Beauty                                284900000
# Music|Fashion                                 237200000
# Clothing|Outfits|Lifestyle                    219400000
# Modeling|Fashion                              217800000
# Nature  landscapes|Science|Photography        206600000
# Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000
# Music|Cinema|Actors/actresses                 194900000

# %%
topfollowers_ind = df_ind.nlargest(10,'Followers')

topfollowers_ind.pivot_table(index="Account", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                       sum
#                 Followers
# Account
# instagram       469600000
# cristiano       400100000
# therock         295800000
# justinbieber    219800000
# virat.kohli     182600000
# priyankachopra   74000000
# nasa             73900000
# shakira          71600000
# davidbeckham     71100000
# shraddhakapoor   68900000

# %%
topfollowers_indo = df_indo.nlargest(10,'Followers')

topfollowers_indo.pivot_table(index="Account", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                            sum
#                      Followers
# Account
# fcbarcelona          105100000
# lalalalisa_m          73100000
# jennierubyjane        62300000
# raffinagita1717       59300000
# 9gag                  58000000
# sooyaaa__             56100000
# roses_are_rosie       55100000
# ayutingting92         50600000
# prillylatuconsina96   45800000
# blackpinkofficial     45200000

# %%
topfollowers_mex = df_mex.nlargest(10,'Followers')

topfollowers_mex.pivot_table(index="Account", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                       sum
#                 Followers
# Account
# dualipa          78700000
# jbalvin          51400000
# karolg           47300000
# lelepons         47300000
# nattinatasha     34900000
# kimberly.loaiza  33400000
# dannapaola       33200000
# luisitocomunica  31000000
# iambeckyg        29300000
# juanpazurita     28100000

# %%
topfollowers_bra = df_bra.nlargest(10,'Followers')

topfollowers_bra.pivot_table(index="Account", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                         sum
#                   Followers
# Account
# neymarjr          169800000
# katyperry         151900000
# championsleague    87900000
# vindiesel          78200000
# shawnmendes        66500000
# ronaldinho         63300000
# camila_cabello     60000000
# anitta             59100000
# whinderssonnunes   57100000
# psg                56000000

# %%
fashion = data[data['Category'].str.contains('Fashion', na=False)]
fashion.head()
# Out:
#   Rank        Account                Title  \
# 1    2    kyliejenner              Kylie 🤍
# 3    4  kendalljenner              Kendall
# 5    6        zendaya              Zendaya
# 6    7  kimkardashian  Kim Kardashian West
# 7    8        beyonce             Beyoncé
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
# 7        https://www.instagram.com/beyonce/                    Music|Fashion
#
#    Followers Audience Country  Authentic engagement  Engagement avg
# 1  308800000    United States               6200000        10100000
# 3  217800000    United States               3400000         5400000
# ...

# %%
pg = data[data['Category'].str.contains('Photography', na=False)]
pg.head()
# Out:
#     Rank     Account                Title  \
# 28    29   instagram            Instagram
# 86    87        nasa                 NASA
# 167  168      natgeo  National Geographic
# 185  186  xxxibgdrgn        권지용(權志龍)
# 421  422  leeyoum262               이유미
#
#                                       Link  \
# 28    https://www.instagram.com/instagram/
# 86         https://www.instagram.com/nasa/
# 167      https://www.instagram.com/natgeo/
# 185  https://www.instagram.com/xxxibgdrgn/
# 421  https://www.instagram.com/leeyoum262/
#
#                                    Category  Followers Audience Country  \
# 28                              Photography  469600000            India
# 86                      Science|Photography   73900000            India
# 167  Nature  landscapes|Science|Photography  206600000    United States
# 185                     Photography|Fashion   20400000        Indonesia
# 421         Photography|Humor|Fun|Happiness    7400000      South Korea
#
# ...

# %%
sports = data[data['Category'].str.contains('Sports', na=False)]
sports.head()
# Out:
#    Rank      Account              Title  \
# 0     1    cristiano  Cristiano Ronaldo
# 2     3     leomessi          Leo Messi
# 10   11     neymarjr              NJ 🇧🇷
# 14   15  virat.kohli        Virat Kohli
# 38   39    kingjames                  👑
#
#                                       Link                   Category  \
# 0     https://www.instagram.com/cristiano/         Sports with a ball
# 2      https://www.instagram.com/leomessi/  Sports with a ball|Family
# 10     https://www.instagram.com/neymarjr/         Sports with a ball
# 14  https://www.instagram.com/virat.kohli/         Sports with a ball
# 38    https://www.instagram.com/kingjames/         Sports with a ball
#
#     Followers Audience Country  Authentic engagement  Engagement avg
# 0   400100000            India               7800000         9500000
# 2   306300000        Argentina               4800000         6500000
# 10  169800000           Brazil               2800000         4000000
# ...

# %%
music = data[data['Category'].str.contains('Music', na=False)]
music.head()
# Out:
#    Rank       Account          Title                                     Link  \
# 4     5   selenagomez   Selena Gomez   https://www.instagram.com/selenagomez/
# 7     8       beyonce       Beyoncé       https://www.instagram.com/beyonce/
# 8     9  arianagrande  Ariana Grande  https://www.instagram.com/arianagrande/
# 9    10  billieeilish  BILLIE EILISH  https://www.instagram.com/billieeilish/
# 11   12  lalalalisa_m           LISA  https://www.instagram.com/lalalalisa_m/
#
#            Category  Followers Audience Country  Authentic engagement  \
# 4   Music|Lifestyle  295800000    United States               2700000
# 7     Music|Fashion  237200000    United States               2500000
# 8             Music  294100000    United States               1700000
# 9             Music  100000000    United States               5300000
# 11            Music   73100000        Indonesia               7500000
#
#     Engagement avg
# 4          3600000
# 7          3600000
# ...

# %%
fn = data[data['Category'].str.contains('Fitness', na=False)]
fn.head()
# Out:
#     Rank          Account                    Title  \
# 27    28          therock                  therock
# 85    86       miakhalifa                   Mia K.
# 96    97             nike                     Nike
# 155  156  thenotoriousmma  Conor McGregor Official
# 182  183        loganpaul               Logan Paul
#
#                                            Link  \
# 27           https://www.instagram.com/therock/
# 85        https://www.instagram.com/miakhalifa/
# 96              https://www.instagram.com/nike/
# 155  https://www.instagram.com/thenotoriousmma/
# 182        https://www.instagram.com/loganpaul/
#
#                                          Category  Followers Audience Country  \
# 27            Cinema|Actors/actresses|Fitness|Gym  295800000            India
# 85                          Fitness|Gym|Lifestyle   27000000            India
# 96   Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000    United States
# ...

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers.Category, topfollowers.Followers, label='Followers', width=0.8, color='skyblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 10 Categories by Followers", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers20.Category, topfollowers20.Followers, label='Followers', width=0.8, color='Chartreuse')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 20 Categories by Followers", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_usa.Followers, color='royalblue', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the US', fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers_usa.Account, topfollowers_usa.Followers, label='Followers', width=0.8, color='Orchid')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Account", fontsize = 16)
plt.title("Top 10 account by Followers in usa", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_bra.Followers, color='MediumVioletRed', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the BRAZIL', fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers_bra.Account, topfollowers_bra.Followers, label='Followers', width=0.8, color='MediumPurple')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Account", fontsize = 16)
plt.title("Top 10 account by Followers in Brazil", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_ind.Followers, color='hotpink', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the INDIA', fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers_ind.Account, topfollowers_ind.Followers, label='Followers', width=0.8, color='SlateBlue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Account", fontsize = 16)
plt.title("Top 10 account by Followers in India", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_usa.Followers, color='orange', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the INDONESIA', fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers_indo.Account, topfollowers_indo.Followers, label='Followers', width=0.8, color='steelblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Account", fontsize = 16)
plt.title("Top 10 account by Followers in Indonesia", fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_usa.Followers, color='MediumPurple', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the Mexico', fontsize = 20)
plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers_mex.Account, topfollowers_mex.Followers, label='Followers', width=0.8, color='cadetblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Account", fontsize = 16)
plt.title("Top 10 account by Followers in Mexico", fontsize = 20)
plt.tight_layout()
